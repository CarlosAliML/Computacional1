# %%
# %matplotlib inline

# %%
3*7
# Out:
# 21

# %%
print('Hello world!')
print('What is your name?')

myName= raw_input()

print('How many times would you like your name to repeat?')

counter=int(raw_input())

print('Nice to meet you')
for x in range(counter):
    print(myName)
# Out:
# Hello world!
# What is your name?
# Alí
# How many times would you like your name to repeat?
# 3
# Nice to meet you
# Alí
# Alí
# Alí

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.linspace(0, 10)

with plt.style.context('fivethirtyeight'):
    plt.plot(x, np.sin(x) + x + np.random.randn(50))
    plt.plot(x, np.sin(x) + 0.5 * x + np.random.randn(50))
    plt.plot(x, np.sin(x) + 2 * x + np.random.randn(50))


plt.show()

# %%
import pandas as pd
pd.set_option('display.mpl_style', 'default')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-15-6e95e3da96cf> in <module>()
# ----> 1 import pandas as pd
#       2 pd.set_option('display.mpl_style', 'default')
#
# ImportError: No module named pandas

# %%
broken_df = pd.read_csv('../Computacional1/Computacional1/Actividad2/San Diego/ Datosfiltrados2015.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ab08ee040528> in <module>()
# ----> 1 broken_df = pd.read_csv('../Computacional1/Computacional1/Actividad2/San Diego/ Datosfiltrados2015.csv')
#
# NameError: name 'pd' is not defined
